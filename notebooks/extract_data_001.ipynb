# %% [markdown]
# ## Extract Data of Site Fundamentus
#
# All credits for the api founded on https://github.com/phoemur/fundamentus/blob/033c5341086299f800f01519ccc857829a4800c6/fundamentus.py#L95

# %% [markdown]
# # 1.0 Libs And Functions

# %%
# data manipulation libs
import pandas as pd
import numpy as np
# date and time libs
import datetime as dt
from datetime import timedelta
# using a soup lib to scrapp the page
import urllib.request
import urllib.parse
# lib to passe cookies
import http.cookiejar
from lxml.html import fragment_fromstring
import re
# libs to clean data exported data
from collections import OrderedDict
from decimal import Decimal

# %%
# personalize class content all the functions i need
class functions(object):
    def format_currency(self, x):
        return "R${:,.2f}".format(x)

    def format_perc(self, x):
        return "{}%".format(x)

    def today(self):
        return dt.date.today()

    def replace_nan(self,df,column,to_replace,repl):
        df[column] = df[column].replace(to_replace,repl)

    def change_type(self,df,column,type):
        df[column] = df[column].astype(type)

    def options(self):
        global pd_options
        pd_options = pd.options.mode.chained_assignment = None

    def column_index(self, df, query_cols):
        cols = df.columns.values
        sidx = np.argsort(cols)
        return sidx[np.searchsorted(cols,query_cols,sorter=sidx)]

    def inicio_mes(self):
        hoje = dt.datetime.today() 
        inicio_mes_data = hoje - timedelta(hoje.day)+ timedelta(days=1)
        return inicio_mes_data
        
    def round_data(self,df,columns_to_round):
        df[columns_to_round] = np.round(df[columns_to_round],2)

    def todecimal(self,string):
        string = string.replace('.', '')
        string = string.replace(',', '.')
        
        if (string.endswith('%')):
            string = string[:-1]
            return Decimal(string) / 100
        else:
            return Decimal(string)


personal_functions = functions()

# %% [markdown]
# # 2.0 Extract Data

# %%
# url to extract'
fundamentus_url = r'https://www.fundamentus.com.br/resultado.php'

# %%
# get the url response
cookie_jar = http.cookiejar.CookieJar()
opener = urllib.request.build_opener(urllib.request.HTTPCookieProcessor(cookie_jar))
opener.addheaders = [('User-agent', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; rv:2.2) Gecko/20110201'),
                         ('Accept', 'text/html, text/plain, text/css, text/sgml, */*;q=0.01')]

# %%
# create a dict
data = {'pl_min': '',
            'pl_max': '',
            'pvp_min': '',
            'pvp_max' : '',
            'psr_min': '',
            'psr_max': '',
            'divy_min': '',
            'divy_max': '',
            'pativos_min': '',
            'pativos_max': '',
            'pcapgiro_min': '',
            'pcapgiro_max': '',
            'pebit_min': '',
            'pebit_max': '',
            'fgrah_min': '',
            'fgrah_max': '',
            'firma_ebit_min': '',
            'firma_ebit_max': '',
            'margemebit_min': '',
            'margemebit_max': '',
            'margemliq_min': '',
            'margemliq_max': '',
            'liqcorr_min': '',
            'liqcorr_max': '',
            'roic_min': '',
            'roic_max': '',
            'roe_min': '',
            'roe_max': '',
            'liq_min': '',
            'liq_max': '',
            'patrim_min': '',
            'patrim_max': '',
            'divbruta_min': '',
            'divbruta_max': '',
            'tx_cresc_rec_min': '',
            'tx_cresc_rec_max': '',
            'setor': '',
            'negociada': 'ON',
            'ordem': '1',
            'x': '28',
            'y': '16'}

# %%
# disable cookies
html = opener.open(fundamentus_url, urllib.parse.urlencode(data).encode('UTF-8'))
html_content = html.read().decode('ISO-8859-1')

# %%
# get the pattern to search inside te html_content
pattern = re.compile('<table id="resultado".*</table>', re.DOTALL)

# %%
# soup the page and get the pure html
final_soup = re.findall(pattern,html_content)[0]

# %%
# formated
final_page = fragment_fromstring(final_soup)

# %%
# create a dict to put the data inside
final_dict = OrderedDict()

# %%
# fuction that return a dict with all elements from the html
def return_function():
    for rows in final_page.xpath('tbody')[0].findall("tr"):
        final_dict.update({rows.getchildren()[0][0].getchildren()[0].text:
        {'Cotacao': personal_functions.todecimal(rows.getchildren()[1].text),
        'P/L': personal_functions.todecimal(rows.getchildren()[2].text),
        'P/VP': personal_functions.todecimal(rows.getchildren()[3].text),
        'PSR': personal_functions.todecimal(rows.getchildren()[4].text),
        'DY': personal_functions.todecimal(rows.getchildren()[5].text),
        'P/Ativo': personal_functions.todecimal(rows.getchildren()[6].text),
        'P/Cap.Giro': personal_functions.todecimal(rows.getchildren()[7].text),
        'P/EBIT': personal_functions.todecimal(rows.getchildren()[8].text),
        'P/ACL': personal_functions.todecimal(rows.getchildren()[9].text),
        'EV/EBIT': personal_functions.todecimal(rows.getchildren()[10].text),
        'EV/EBITDA': personal_functions.todecimal(rows.getchildren()[11].text),
        'Mrg.Ebit': personal_functions.todecimal(rows.getchildren()[12].text),
        'Mrg.Liq.': personal_functions.todecimal(rows.getchildren()[13].text),
        'Liq.Corr.': personal_functions.todecimal(rows.getchildren()[14].text),
        'ROIC': personal_functions.todecimal(rows.getchildren()[15].text),
        'ROE': personal_functions.todecimal(rows.getchildren()[16].text),
        'Liq.2meses': personal_functions.todecimal(rows.getchildren()[17].text),
        'Pat.Liq': personal_functions.todecimal(rows.getchildren()[18].text),
        'Div.Brut/Pat.': personal_functions.todecimal(rows.getchildren()[19].text),
        'Cresc.5anos': personal_functions.todecimal(rows.getchildren()[20].text)}})
    return final_dict
final_dict = return_function()

# %%
final_dict
# Out:
# OrderedDict([('AESB3',
#               {'Cotacao': Decimal('9.38'),
#                'P/L': Decimal('-1387.24'),
#                'P/VP': Decimal('1.35'),
#                'PSR': Decimal('2.005'),
#                'DY': Decimal('0.0094'),
#                'P/Ativo': Decimal('0.374'),
#                'P/Cap.Giro': Decimal('1.90'),
#                'P/EBIT': Decimal('11.08'),
#                'P/ACL': Decimal('-1.00'),
#                'EV/EBIT': Decimal('19.79'),
#                'EV/EBITDA': Decimal('10.02'),
#                'Mrg.Ebit': Decimal('0.181'),
#                'Mrg.Liq.': Decimal('0.0537'),
#                'Liq.Corr.': Decimal('3.63'),
#                'ROIC': Decimal('0.0448'),
#                'ROE': Decimal('-0.001'),
#                'Liq.2meses': Decimal('20667900.00'),
#                'Pat.Liq': Decimal('4175170000.00'),
#                'Div.Brut/Pat.': Decimal('1.89'),
#                'Cresc.5anos': Decimal('1.3024')}),
#              ('ONCO3',
#               {'Cotacao': Decimal('6.12'),
#                'P/L': Decimal('-318.86'),
#                'P/VP': Decimal('1.51'),
#                'PSR': Decimal('0.838'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.419'),
#                'P/Cap.Giro': Decimal('4.95'),
#                'P/EBIT': Decimal('8.83'),
#                'P/ACL': Decimal('-1.16'),
#                'EV/EBIT': Decimal('15.75'),
#                'EV/EBITDA': Decimal('10.60'),
#                'Mrg.Ebit': Decimal('0.0949'),
#                'Mrg.Liq.': Decimal('0.0109'),
#                'Liq.Corr.': Decimal('1.42'),
#                'ROIC': Decimal('0.0557'),
#                'ROE': Decimal('-0.0047'),
#                'Liq.2meses': Decimal('8085020.00'),
#                'Pat.Liq': Decimal('2014190000.00'),
#                'Div.Brut/Pat.': Decimal('1.48'),
#                'Cresc.5anos': Decimal('0.00')}),
#              ('RAIL3',
#               {'Cotacao': Decimal('16.91'),
#                'P/L': Decimal('-282.74'),
#                'P/VP': Decimal('2.08'),
#                'PSR': Decimal('3.433'),
#                'DY': Decimal('0.0011'),
#                'P/Ativo': Decimal('0.689'),
#                'P/Cap.Giro': Decimal('6.82'),
#                'P/EBIT': Decimal('14.18'),
#                'P/ACL': Decimal('-1.56'),
#                'EV/EBIT': Decimal('18.79'),
#                'EV/EBITDA': Decimal('9.95'),
#                'Mrg.Ebit': Decimal('0.2421'),
#                'Mrg.Liq.': Decimal('-0.0124'),
#                'Liq.Corr.': Decimal('1.83'),
#                'ROIC': Decimal('0.0577'),
#                'ROE': Decimal('-0.0074'),
#                'Liq.2meses': Decimal('268912000.00'),
#                'Pat.Liq': Decimal('15061000000.00'),
#                'Div.Brut/Pat.': Decimal('1.11'),
#                'Cresc.5anos': Decimal('0.077')}),
#              ('DMMO3',
#               {'Cotacao': Decimal('1.86'),
#                'P/L': Decimal('-258.31'),
#                'P/VP': Decimal('-1.71'),
#                'PSR': Decimal('2.851'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('3.341'),
#                'P/Cap.Giro': Decimal('11.89'),
#                'P/EBIT': Decimal('6.36'),
#                'P/ACL': Decimal('-1.37'),
#                'EV/EBIT': Decimal('5.89'),
#                'EV/EBITDA': Decimal('5.41'),
#                'Mrg.Ebit': Decimal('0.4481'),
#                'Mrg.Liq.': Decimal('-0.011'),
#                'Liq.Corr.': Decimal('2.25'),
#                'ROIC': Decimal('0.7039'),
#                'ROE': Decimal('0.0066'),
#                'Liq.2meses': Decimal('17338800.00'),
#                'Pat.Liq': Decimal('-553275000.00'),
#                'Div.Brut/Pat.': Decimal('0.00'),
#                'Cresc.5anos': Decimal('-0.1737')}),
#              ('ELMD3',
#               {'Cotacao': Decimal('9.70'),
#                'P/L': Decimal('-165.61'),
#                'P/VP': Decimal('1.84'),
#                'PSR': Decimal('1.941'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.680'),
#                'P/Cap.Giro': Decimal('-6.77'),
#                'P/EBIT': Decimal('15.60'),
#                'P/ACL': Decimal('-1.80'),
#                'EV/EBIT': Decimal('21.78'),
#                'EV/EBITDA': Decimal('9.95'),
#                'Mrg.Ebit': Decimal('0.1244'),
#                'Mrg.Liq.': Decimal('0.0024'),
#                'Liq.Corr.': Decimal('0.64'),
#                'ROIC': Decimal('0.0504'),
#                'ROE': Decimal('-0.0111'),
#                'Liq.2meses': Decimal('3058160.00'),
#                'Pat.Liq': Decimal('739445000.00'),
#                'Div.Brut/Pat.': Decimal('0.91'),
#                'Cresc.5anos': Decimal('1.011')}),
#              ('HAPV3',
#               {'Cotacao': Decimal('4.54'),
#                'P/L': Decimal('-124.49'),
#                'P/VP': Decimal('0.66'),
#                'PSR': Decimal('1.634'),
#                'DY': Decimal('0.0006'),
#                'P/Ativo': Decimal('0.456'),
#                'P/Cap.Giro': Decimal('120.67'),
#                'P/EBIT': Decimal('-91.62'),
#                'P/ACL': Decimal('-2.14'),
#                'EV/EBIT': Decimal('-111.35'),
#                'EV/EBITDA': Decimal('27.44'),
#                'Mrg.Ebit': Decimal('-0.0178'),
#                'Mrg.Liq.': Decimal('-0.013'),
#                'Liq.Corr.': Decimal('1.04'),
#                'ROIC': Decimal('-0.0053'),
#                'ROE': Decimal('-0.0053'),
#                'Liq.2meses': Decimal('391648000.00'),
#                'Pat.Liq': Decimal('49053700000.00'),
#                'Div.Brut/Pat.': Decimal('0.22'),
#                'Cresc.5anos': Decimal('0.5325')}),
#              ('CSAB4',
#               {'Cotacao': Decimal('42.00'),
#                'P/L': Decimal('-81.37'),
#                'P/VP': Decimal('1.69'),
#                'PSR': Decimal('68.051'),
#                'DY': Decimal('0.0267'),
#                'P/Ativo': Decimal('0.831'),
#                'P/Cap.Giro': Decimal('0.00'),
#                'P/EBIT': Decimal('-34.85'),
#                'P/ACL': Decimal('0.00'),
#                'EV/EBIT': Decimal('0.00'),
#                'EV/EBITDA': Decimal('0.00'),
#                'Mrg.Ebit': Decimal('-1.9525'),
#                'Mrg.Liq.': Decimal('-0.8363'),
#                'Liq.Corr.': Decimal('0.00'),
#                'ROIC': Decimal('0.00'),
#                'ROE': Decimal('-0.0208'),
#                'Liq.2meses': Decimal('1017.07'),
#                'Pat.Liq': Decimal('190979000.00'),
#                'Div.Brut/Pat.': Decimal('0.00'),
#                'Cresc.5anos': Decimal('-0.2884')}),
#              ('CSAB3',
#               {'Cotacao': Decimal('41.00'),
#                'P/L': Decimal('-79.43'),
#                'P/VP': Decimal('1.65'),
#                'PSR': Decimal('66.430'),
#                'DY': Decimal('0.0248'),
#                'P/Ativo': Decimal('0.811'),
#                'P/Cap.Giro': Decimal('0.00'),
#                'P/EBIT': Decimal('-34.02'),
#                'P/ACL': Decimal('0.00'),
#                'EV/EBIT': Decimal('0.00'),
#                'EV/EBITDA': Decimal('0.00'),
#                'Mrg.Ebit': Decimal('-1.9525'),
#                'Mrg.Liq.': Decimal('-0.8363'),
#                'Liq.Corr.': Decimal('0.00'),
#                'ROIC': Decimal('0.00'),
#                'ROE': Decimal('-0.0208'),
#                'Liq.2meses': Decimal('100.00'),
#                'Pat.Liq': Decimal('190979000.00'),
#                'Div.Brut/Pat.': Decimal('0.00'),
#                'Cresc.5anos': Decimal('-0.2884')}),
#              ('TPIS3',
#               {'Cotacao': Decimal('1.10'),
#                'P/L': Decimal('-70.89'),
#                'P/VP': Decimal('0.21'),
#                'PSR': Decimal('0.170'),
#                'DY': Decimal('0.017'),
#                'P/Ativo': Decimal('0.064'),
#                'P/Cap.Giro': Decimal('-0.58'),
#                'P/EBIT': Decimal('0.97'),
#                'P/ACL': Decimal('-0.10'),
#                'EV/EBIT': Decimal('9.12'),
#                'EV/EBITDA': Decimal('4.15'),
#                'Mrg.Ebit': Decimal('0.1758'),
#                'Mrg.Liq.': Decimal('-0.0045'),
#                'Liq.Corr.': Decimal('0.34'),
#                'ROIC': Decimal('0.0696'),
#                'ROE': Decimal('-0.0029'),
#                'Liq.2meses': Decimal('535493.00'),
#                'Pat.Liq': Decimal('926523000.00'),
#                'Div.Brut/Pat.': Decimal('1.85'),
#                'Cresc.5anos': Decimal('-0.0166')}),
#              ('YDUQ3',
#               {'Cotacao': Decimal('9.81'),
#                'P/L': Decimal('-64.01'),
#                'P/VP': Decimal('1.00'),
#                'PSR': Decimal('0.672'),
#                'DY': Decimal('0.0129'),
#                'P/Ativo': Decimal('0.305'),
#                'P/Cap.Giro': Decimal('2.04'),
#                'P/EBIT': Decimal('5.57'),
#                'P/ACL': Decimal('-0.75'),
#                'EV/EBIT': Decimal('13.17'),
#                'EV/EBITDA': Decimal('5.76'),
#                'Mrg.Ebit': Decimal('0.1207'),
#                'Mrg.Liq.': Decimal('-0.0101'),
#                'Liq.Corr.': Decimal('2.07'),
#                'ROIC': Decimal('0.0669'),
#                'ROE': Decimal('-0.0157'),
#                'Liq.2meses': Decimal('88672300.00'),
#                'Pat.Liq': Decimal('3024090000.00'),
#                'Div.Brut/Pat.': Decimal('1.89'),
#                'Cresc.5anos': Decimal('0.066')}),
#              ('MTIG4',
#               {'Cotacao': Decimal('23.00'),
#                'P/L': Decimal('-52.59'),
#                'P/VP': Decimal('-30.96'),
#                'PSR': Decimal('72.916'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('35.553'),
#                'P/Cap.Giro': Decimal('-23.24'),
#                'P/EBIT': Decimal('-94.24'),
#                'P/ACL': Decimal('-18.86'),
#                'EV/EBIT': Decimal('-97.68'),
#                'EV/EBITDA': Decimal('-108.19'),
#                'Mrg.Ebit': Decimal('-0.7737'),
#                'Mrg.Liq.': Decimal('-1.3864'),
#                'Liq.Corr.': Decimal('0.15'),
#                'ROIC': Decimal('-0.4486'),
#                'ROE': Decimal('0.5887'),
#                'Liq.2meses': Decimal('56.10'),
#                'Pat.Liq': Decimal('-90894800.00'),
#                'Div.Brut/Pat.': Decimal('-1.13'),
#                'Cresc.5anos': Decimal('-0.262')}),
#              ('MGLU3',
#               {'Cotacao': Decimal('2.63'),
#                'P/L': Decimal('-47.96'),
#                'P/VP': Decimal('1.64'),
#                'PSR': Decimal('0.500'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.493'),
#                'P/Cap.Giro': Decimal('2.35'),
#                'P/EBIT': Decimal('20.67'),
#                'P/ACL': Decimal('-3.99'),
#                'EV/EBIT': Decimal('26.54'),
#                'EV/EBITDA': Decimal('12.03'),
#                'Mrg.Ebit': Decimal('0.0242'),
#                'Mrg.Liq.': Decimal('-0.0104'),
#                'Liq.Corr.': Decimal('1.58'),
#                'ROIC': Decimal('0.034'),
#                'ROE': Decimal('-0.0343'),
#                'Liq.2meses': Decimal('744596000.00'),
#                'Pat.Liq': Decimal('10805300000.00'),
#                'Div.Brut/Pat.': Decimal('0.66'),
#                'Cresc.5anos': Decimal('0.2794')}),
#              ('HBSA3',
#               {'Cotacao': Decimal('2.27'),
#                'P/L': Decimal('-44.13'),
#                'P/VP': Decimal('1.18'),
#                'PSR': Decimal('1.147'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.258'),
#                'P/Cap.Giro': Decimal('2.05'),
#                'P/EBIT': Decimal('9.84'),
#                'P/ACL': Decimal('-0.46'),
#                'EV/EBIT': Decimal('32.46'),
#                'EV/EBITDA': Decimal('10.74'),
#                'Mrg.Ebit': Decimal('0.1165'),
#                'Mrg.Liq.': Decimal('-0.026'),
#                'Liq.Corr.': Decimal('2.36'),
#                'ROIC': Decimal('0.0307'),
#                'ROE': Decimal('-0.0268'),
#                'Liq.2meses': Decimal('11255200.00'),
#                'Pat.Liq': Decimal('1461770000.00'),
#                'Div.Brut/Pat.': Decimal('3.28'),
#                'Cresc.5anos': Decimal('0.1899')}),
#              ('ESPA3',
#               {'Cotacao': Decimal('1.15'),
#                'P/L': Decimal('-41.33'),
#                'P/VP': Decimal('0.61'),
#                'PSR': Decimal('0.508'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.200'),
#                'P/Cap.Giro': Decimal('1.43'),
#                'P/EBIT': Decimal('8.54'),
#                'P/ACL': Decimal('-0.64'),
#                'EV/EBIT': Decimal('25.17'),
#                'EV/EBITDA': Decimal('9.83'),
#                'Mrg.Ebit': Decimal('0.0595'),
#                'Mrg.Liq.': Decimal('-0.0165'),
#                'Liq.Corr.': Decimal('1.65'),
#                'ROIC': Decimal('0.0245'),
#                'ROE': Decimal('-0.0147'),
#                'Liq.2meses': Decimal('7667380.00'),
#                'Pat.Liq': Decimal('684239000.00'),
#                'Div.Brut/Pat.': Decimal('1.29'),
#                'Cresc.5anos': Decimal('0.0843')}),
#              ('ORVR3',
#               {'Cotacao': Decimal('32.26'),
#                'P/L': Decimal('-36.52'),
#                'P/VP': Decimal('5.59'),
#                'PSR': Decimal('3.829'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('1.365'),
#                'P/Cap.Giro': Decimal('31.18'),
#                'P/EBIT': Decimal('23.59'),
#                'P/ACL': Decimal('-2.61'),
#                'EV/EBIT': Decimal('29.55'),
#                'EV/EBITDA': Decimal('13.80'),
#                'Mrg.Ebit': Decimal('0.1623'),
#                'Mrg.Liq.': Decimal('-0.0896'),
#                'Liq.Corr.': Decimal('1.25'),
#                'ROIC': Decimal('0.0615'),
#                'ROE': Decimal('-0.1529'),
#                'Liq.2meses': Decimal('17424500.00'),
#                'Pat.Liq': Decimal('412995000.00'),
#                'Div.Brut/Pat.': Decimal('1.48'),
#                'Cresc.5anos': Decimal('0.5721')}),
#              ('CBEE3',
#               {'Cotacao': Decimal('13.49'),
#                'P/L': Decimal('-31.80'),
#                'P/VP': Decimal('0.68'),
#                'PSR': Decimal('0.392'),
#                'DY': Decimal('0.0061'),
#                'P/Ativo': Decimal('0.194'),
#                'P/Cap.Giro': Decimal('-1.35'),
#                'P/EBIT': Decimal('2.66'),
#                'P/ACL': Decimal('-0.37'),
#                'EV/EBIT': Decimal('6.59'),
#                'EV/EBITDA': Decimal('4.53'),
#                'Mrg.Ebit': Decimal('0.1477'),
#                'Mrg.Liq.': Decimal('-0.0123'),
#                'Liq.Corr.': Decimal('0.58'),
#                'ROIC': Decimal('0.0796'),
#                'ROE': Decimal('-0.0215'),
#                'Liq.2meses': Decimal('1336.73'),
#                'Pat.Liq': Decimal('4749900000.00'),
#                'Div.Brut/Pat.': Decimal('1.05'),
#                'Cresc.5anos': Decimal('0.1148')}),
#              ('SMFT3',
#               {'Cotacao': Decimal('13.10'),
#                'P/L': Decimal('-27.85'),
#                'P/VP': Decimal('1.85'),
#                'PSR': Decimal('2.927'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.692'),
#                'P/Cap.Giro': Decimal('4.42'),
#                'P/EBIT': Decimal('109.95'),
#                'P/ACL': Decimal('-2.09'),
#                'EV/EBIT': Decimal('115.16'),
#                'EV/EBITDA': Decimal('8.51'),
#                'Mrg.Ebit': Decimal('0.0266'),
#                'Mrg.Liq.': Decimal('-0.1036'),
#                'Liq.Corr.': Decimal('2.14'),
#                'ROIC': Decimal('0.0086'),
#                'ROE': Decimal('-0.0665'),
#                'Liq.2meses': Decimal('22274800.00'),
#                'Pat.Liq': Decimal('4147930000.00'),
#                'Div.Brut/Pat.': Decimal('0.74'),
#                'Cresc.5anos': Decimal('0.1998')}),
#              ('RCSL3',
#               {'Cotacao': Decimal('2.09'),
#                'P/L': Decimal('-25.50'),
#                'P/VP': Decimal('-2.03'),
#                'PSR': Decimal('1.125'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('1.206'),
#                'P/Cap.Giro': Decimal('13.01'),
#                'P/EBIT': Decimal('375.53'),
#                'P/ACL': Decimal('-1.06'),
#                'EV/EBIT': Decimal('371.24'),
#                'EV/EBITDA': Decimal('59.61'),
#                'Mrg.Ebit': Decimal('0.003'),
#                'Mrg.Liq.': Decimal('-0.044'),
#                'Liq.Corr.': Decimal('1.25'),
#                'ROIC': Decimal('0.0034'),
#                'ROE': Decimal('0.0796'),
#                'Liq.2meses': Decimal('324470.00'),
#                'Pat.Liq': Decimal('-39014000.00'),
#                'Div.Brut/Pat.': Decimal('-0.00'),
#                'Cresc.5anos': Decimal('1.5121')}),
#              ('AERI3',
#               {'Cotacao': Decimal('1.00'),
#                'P/L': Decimal('-21.78'),
#                'P/VP': Decimal('0.81'),
#                'PSR': Decimal('0.319'),
#                'DY': Decimal('0.0207'),
#                'P/Ativo': Decimal('0.222'),
#                'P/Cap.Giro': Decimal('0.62'),
#                'P/EBIT': Decimal('4.34'),
#                'P/ACL': Decimal('-3.30'),
#                'EV/EBIT': Decimal('8.40'),
#                'EV/EBITDA': Decimal('6.43'),
#                'Mrg.Ebit': Decimal('0.0735'),
#                'Mrg.Liq.': Decimal('-0.0146'),
#                'Liq.Corr.': Decimal('2.19'),
#                'ROIC': Decimal('0.0855'),
#                'ROE': Decimal('-0.0373'),
#                'Liq.2meses': Decimal('10187100.00'),
#                'Pat.Liq': Decimal('942087000.00'),
#                'Div.Brut/Pat.': Decimal('1.67'),
#                'Cresc.5anos': Decimal('-0.0921')}),
#              ('AGXY3',
#               {'Cotacao': Decimal('8.35'),
#                'P/L': Decimal('-21.70'),
#                'P/VP': Decimal('1.11'),
#                'PSR': Decimal('0.133'),
#                'DY': Decimal('0.0201'),
#                'P/Ativo': Decimal('0.164'),
#                'P/Cap.Giro': Decimal('1.44'),
#                'P/EBIT': Decimal('3.00'),
#                'P/ACL': Decimal('-4.72'),
#                'EV/EBIT': Decimal('5.43'),
#                'EV/EBITDA': Decimal('4.50'),
#                'Mrg.Ebit': Decimal('0.0443'),
#                'Mrg.Liq.': Decimal('-0.0061'),
#                'Liq.Corr.': Decimal('1.16'),
#                'ROIC': Decimal('0.1133'),
#                'ROE': Decimal('-0.0513'),
#                'Liq.2meses': Decimal('613320.00'),
#                'Pat.Liq': Decimal('1282050000.00'),
#                'Div.Brut/Pat.': Decimal('1.52'),
#                'Cresc.5anos': Decimal('0.8742')}),
#              ('DASA3',
#               {'Cotacao': Decimal('12.83'),
#                'P/L': Decimal('-21.18'),
#                'P/VP': Decimal('0.98'),
#                'PSR': Decimal('0.574'),
#                'DY': Decimal('0.023'),
#                'P/Ativo': Decimal('0.286'),
#                'P/Cap.Giro': Decimal('6.33'),
#                'P/EBIT': Decimal('10.28'),
#                'P/ACL': Decimal('-0.65'),
#                'EV/EBIT': Decimal('21.46'),
#                'EV/EBITDA': Decimal('8.27'),
#                'Mrg.Ebit': Decimal('0.0559'),
#                'Mrg.Liq.': Decimal('-0.0271'),
#                'Liq.Corr.': Decimal('1.20'),
#                'ROIC': Decimal('0.0322'),
#                'ROE': Decimal('-0.0462'),
#                'Liq.2meses': Decimal('3724900.00'),
#                'Pat.Liq': Decimal('7352800000.00'),
#                'Div.Brut/Pat.': Decimal('1.36'),
#                'Cresc.5anos': Decimal('0.3766')}),
#              ('VIIA3',
#               {'Cotacao': Decimal('1.98'),
#                'P/L': Decimal('-21.10'),
#                'P/VP': Decimal('0.57'),
#                'PSR': Decimal('0.105'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.093'),
#                'P/Cap.Giro': Decimal('-0.90'),
#                'P/EBIT': Decimal('1.48'),
#                'P/ACL': Decimal('-0.24'),
#                'EV/EBIT': Decimal('5.27'),
#                'EV/EBITDA': Decimal('3.47'),
#                'Mrg.Ebit': Decimal('0.0707'),
#                'Mrg.Liq.': Decimal('-0.005'),
#                'Liq.Corr.': Decimal('0.81'),
#                'ROIC': Decimal('0.083'),
#                'ROE': Decimal('-0.0272'),
#                'Liq.2meses': Decimal('214076000.00'),
#                'Pat.Liq': Decimal('5505000000.00'),
#                'Div.Brut/Pat.': Decimal('1.69'),
#                'Cresc.5anos': Decimal('0.0475')}),
#              ('TRAD3',
#               {'Cotacao': Decimal('2.06'),
#                'P/L': Decimal('-18.87'),
#                'P/VP': Decimal('1.01'),
#                'PSR': Decimal('6.059'),
#                'DY': Decimal('0.0001'),
#                'P/Ativo': Decimal('0.948'),
#                'P/Cap.Giro': Decimal('2.81'),
#                'P/EBIT': Decimal('-6.97'),
#                'P/ACL': Decimal('2.83'),
#                'EV/EBIT': Decimal('-4.45'),
#                'EV/EBITDA': Decimal('-5.54'),
#                'Mrg.Ebit': Decimal('-0.8698'),
#                'Mrg.Liq.': Decimal('-0.319'),
#                'Liq.Corr.': Decimal('6.95'),
#                'ROIC': Decimal('-0.2097'),
#                'ROE': Decimal('-0.0535'),
#                'Liq.2meses': Decimal('3550700.00'),
#                'Pat.Liq': Decimal('571473000.00'),
#                'Div.Brut/Pat.': Decimal('0.01'),
#                'Cresc.5anos': Decimal('0.00')}),
#              ('AALR3',
#               {'Cotacao': Decimal('20.22'),
#                'P/L': Decimal('-17.65'),
#                'P/VP': Decimal('2.23'),
#                'PSR': Decimal('2.190'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.909'),
#                'P/Cap.Giro': Decimal('-29.16'),
#                'P/EBIT': Decimal('79.59'),
#                'P/ACL': Decimal('-2.35'),
#                'EV/EBIT': Decimal('101.63'),
#                'EV/EBITDA': Decimal('20.87'),
#                'Mrg.Ebit': Decimal('0.0275'),
#                'Mrg.Liq.': Decimal('-0.118'),
#                'Liq.Corr.': Decimal('0.86'),
#                'ROIC': Decimal('0.0132'),
#                'ROE': Decimal('-0.1263'),
#                'Liq.2meses': Decimal('7997060.00'),
#                'Pat.Liq': Decimal('1072550000.00'),
#                'Div.Brut/Pat.': Decimal('0.85'),
#                'Cresc.5anos': Decimal('0.0116')}),
#              ('ZAMP3',
#               {'Cotacao': Decimal('4.46'),
#                'P/L': Decimal('-16.56'),
#                'P/VP': Decimal('0.84'),
#                'PSR': Decimal('0.350'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.307'),
#                'P/Cap.Giro': Decimal('8.37'),
#                'P/EBIT': Decimal('16.62'),
#                'P/ACL': Decimal('-0.80'),
#                'EV/EBIT': Decimal('23.78'),
#                'EV/EBITDA': Decimal('3.67'),
#                'Mrg.Ebit': Decimal('0.0211'),
#                'Mrg.Liq.': Decimal('-0.0211'),
#                'Liq.Corr.': Decimal('1.17'),
#                'ROIC': Decimal('0.023'),
#                'ROE': Decimal('-0.0509'),
#                'Liq.2meses': Decimal('8976020.00'),
#                'Pat.Liq': Decimal('1456990000.00'),
#                'Div.Brut/Pat.': Decimal('0.74'),
#                'Cresc.5anos': Decimal('0.0956')}),
#              ('LIGT3',
#               {'Cotacao': Decimal('4.62'),
#                'P/L': Decimal('-16.29'),
#                'P/VP': Decimal('0.20'),
#                'PSR': Decimal('0.119'),
#                'DY': Decimal('0.0549'),
#                'P/Ativo': Decimal('0.062'),
#                'P/Cap.Giro': Decimal('0.73'),
#                'P/EBIT': Decimal('1.06'),
#                'P/ACL': Decimal('-0.15'),
#                'EV/EBIT': Decimal('6.12'),
#                'EV/EBITDA': Decimal('4.24'),
#                'Mrg.Ebit': Decimal('0.1126'),
#                'Mrg.Liq.': Decimal('-0.0073'),
#                'Liq.Corr.': Decimal('1.41'),
#                'ROIC': Decimal('0.0722'),
#                'ROE': Decimal('-0.0123'),
#                'Liq.2meses': Decimal('25673400.00'),
#                'Pat.Liq': Decimal('8557000000.00'),
#                'Div.Brut/Pat.': Decimal('1.44'),
#                'Cresc.5anos': Decimal('0.046')}),
#              ('CASH3',
#               {'Cotacao': Decimal('1.22'),
#                'P/L': Decimal('-16.14'),
#                'P/VP': Decimal('1.36'),
#                'PSR': Decimal('2.888'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.798'),
#                'P/Cap.Giro': Decimal('2.25'),
#                'P/EBIT': Decimal('-6.13'),
#                'P/ACL': Decimal('3.01'),
#                'EV/EBIT': Decimal('-1.77'),
#                'EV/EBITDA': Decimal('-1.90'),
#                'Mrg.Ebit': Decimal('-0.4713'),
#                'Mrg.Liq.': Decimal('-0.2257'),
#                'Liq.Corr.': Decimal('2.13'),
#                'ROIC': Decimal('-0.3092'),
#                'ROE': Decimal('-0.0842'),
#                'Liq.2meses': Decimal('44112900.00'),
#                'Pat.Liq': Decimal('776485000.00'),
#                'Div.Brut/Pat.': Decimal('0.00'),
#                'Cresc.5anos': Decimal('0.7533')}),
#              ('DTCY3',
#               {'Cotacao': Decimal('5.35'),
#                'P/L': Decimal('-15.30'),
#                'P/VP': Decimal('-25.48'),
#                'PSR': Decimal('7.595'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('5.579'),
#                'P/Cap.Giro': Decimal('-12.72'),
#                'P/EBIT': Decimal('-22.08'),
#                'P/ACL': Decimal('-6.16'),
#                'EV/EBIT': Decimal('-22.42'),
#                'EV/EBITDA': Decimal('38.71'),
#                'Mrg.Ebit': Decimal('-0.344'),
#                'Mrg.Liq.': Decimal('-0.4964'),
#                'Liq.Corr.': Decimal('0.42'),
#                'ROIC': Decimal('-0.2658'),
#                'ROE': Decimal('1.6654'),
#                'Liq.2meses': Decimal('443.37'),
#                'Pat.Liq': Decimal('-2337000.00'),
#                'Div.Brut/Pat.': Decimal('-0.58'),
#                'Cresc.5anos': Decimal('-0.1735')}),
#              ('COGN3',
#               {'Cotacao': Decimal('2.07'),
#                'P/L': Decimal('-14.92'),
#                'P/VP': Decimal('0.31'),
#                'PSR': Decimal('0.794'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.148'),
#                'P/Cap.Giro': Decimal('4.14'),
#                'P/EBIT': Decimal('5.16'),
#                'P/ACL': Decimal('-0.48'),
#                'EV/EBIT': Decimal('13.11'),
#                'EV/EBITDA': Decimal('6.88'),
#                'Mrg.Ebit': Decimal('0.1539'),
#                'Mrg.Liq.': Decimal('-0.0581'),
#                'Liq.Corr.': Decimal('1.24'),
#                'ROIC': Decimal('0.0323'),
#                'ROE': Decimal('-0.021'),
#                'Liq.2meses': Decimal('114559000.00'),
#                'Pat.Liq': Decimal('12389900000.00'),
#                'Div.Brut/Pat.': Decimal('0.66'),
#                'Cresc.5anos': Decimal('-0.0696')}),
#              ('SCAR3',
#               {'Cotacao': Decimal('16.86'),
#                'P/L': Decimal('-14.85'),
#                'P/VP': Decimal('0.65'),
#                'PSR': Decimal('3.214'),
#                'DY': Decimal('0.0085'),
#                'P/Ativo': Decimal('0.263'),
#                'P/Cap.Giro': Decimal('3.05'),
#                'P/EBIT': Decimal('6.77'),
#                'P/ACL': Decimal('-0.60'),
#                'EV/EBIT': Decimal('19.41'),
#                'EV/EBITDA': Decimal('13.69'),
#                'Mrg.Ebit': Decimal('0.4751'),
#                'Mrg.Liq.': Decimal('-0.2253'),
#                'Liq.Corr.': Decimal('2.25'),
#                'ROIC': Decimal('0.0423'),
#                'ROE': Decimal('-0.0436'),
#                'Liq.2meses': Decimal('116580.00'),
#                'Pat.Liq': Decimal('1503850000.00'),
#                'Div.Brut/Pat.': Decimal('1.41'),
#                'Cresc.5anos': Decimal('-0.1453')}),
#              ('NTCO3',
#               {'Cotacao': Decimal('10.66'),
#                'P/L': Decimal('-11.57'),
#                'P/VP': Decimal('0.64'),
#                'PSR': Decimal('0.392'),
#                'DY': Decimal('0.0123'),
#                'P/Ativo': Decimal('0.271'),
#                'P/Cap.Giro': Decimal('4.36'),
#                'P/EBIT': Decimal('10.75'),
#                'P/ACL': Decimal('-0.93'),
#                'EV/EBIT': Decimal('17.36'),
#                'EV/EBITDA': Decimal('5.94'),
#                'Mrg.Ebit': Decimal('0.0365'),
#                'Mrg.Liq.': Decimal('-0.0339'),
#                'Liq.Corr.': Decimal('1.27'),
#                'ROIC': Decimal('0.0313'),
#                'ROE': Decimal('-0.0554'),
#                'Liq.2meses': Decimal('219165000.00'),
#                'Pat.Liq': Decimal('22985000000.00'),
#                'Div.Brut/Pat.': Decimal('0.60'),
#                'Cresc.5anos': Decimal('-0.0227')}),
#              ('CEAB3',
#               {'Cotacao': Decimal('2.16'),
#                'P/L': Decimal('-11.56'),
#                'P/VP': Decimal('0.24'),
#                'PSR': Decimal('0.109'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.074'),
#                'P/Cap.Giro': Decimal('0.81'),
#                'P/EBIT': Decimal('12.41'),
#                'P/ACL': Decimal('-0.31'),
#                'EV/EBIT': Decimal('33.75'),
#                'EV/EBITDA': Decimal('4.47'),
#                'Mrg.Ebit': Decimal('0.0088'),
#                'Mrg.Liq.': Decimal('-0.0094'),
#                'Liq.Corr.': Decimal('1.25'),
#                'ROIC': Decimal('0.0085'),
#                'ROE': Decimal('-0.0207'),
#                'Liq.2meses': Decimal('13233000.00'),
#                'Pat.Liq': Decimal('2785870000.00'),
#                'Div.Brut/Pat.': Decimal('0.86'),
#                'Cresc.5anos': Decimal('0.2253')}),
#              ('CLSA3',
#               {'Cotacao': Decimal('4.80'),
#                'P/L': Decimal('-10.42'),
#                'P/VP': Decimal('1.22'),
#                'PSR': Decimal('1.842'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.978'),
#                'P/Cap.Giro': Decimal('1.64'),
#                'P/EBIT': Decimal('-6.71'),
#                'P/ACL': Decimal('1.79'),
#                'EV/EBIT': Decimal('-3.38'),
#                'EV/EBITDA': Decimal('-4.16'),
#                'Mrg.Ebit': Decimal('-0.2746'),
#                'Mrg.Liq.': Decimal('-0.1767'),
#                'Liq.Corr.': Decimal('5.03'),
#                'ROIC': Decimal('-0.3513'),
#                'ROE': Decimal('-0.117'),
#                'Liq.2meses': Decimal('3427820.00'),
#                'Pat.Liq': Decimal('740258000.00'),
#                'Div.Brut/Pat.': Decimal('0.10'),
#                'Cresc.5anos': Decimal('0.00')}),
#              ('EMBR3',
#               {'Cotacao': Decimal('13.89'),
#                'P/L': Decimal('-9.69'),
#                'P/VP': Decimal('0.77'),
#                'PSR': Decimal('0.507'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.192'),
#                'P/Cap.Giro': Decimal('0.78'),
#                'P/EBIT': Decimal('6.71'),
#                'P/ACL': Decimal('-1.16'),
#                'EV/EBIT': Decimal('11.80'),
#                'EV/EBITDA': Decimal('7.14'),
#                'Mrg.Ebit': Decimal('0.0756'),
#                'Mrg.Liq.': Decimal('-0.0568'),
#                'Liq.Corr.': Decimal('1.77'),
#                'ROIC': Decimal('0.038'),
#                'ROE': Decimal('-0.0798'),
#                'Liq.2meses': Decimal('107357000.00'),
#                'Pat.Liq': Decimal('13311700000.00'),
#                'Div.Brut/Pat.': Decimal('1.27'),
#                'Cresc.5anos': Decimal('0.1017')}),
#              ('SHOW3',
#               {'Cotacao': Decimal('2.15'),
#                'P/L': Decimal('-9.24'),
#                'P/VP': Decimal('1.02'),
#                'PSR': Decimal('0.478'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.239'),
#                'P/Cap.Giro': Decimal('1.95'),
#                'P/EBIT': Decimal('3.28'),
#                'P/ACL': Decimal('-2.41'),
#                'EV/EBIT': Decimal('0.73'),
#                'EV/EBITDA': Decimal('0.64'),
#                'Mrg.Ebit': Decimal('0.1459'),
#                'Mrg.Liq.': Decimal('-0.0438'),
#                'Liq.Corr.': Decimal('1.23'),
#                'ROIC': Decimal('0.2163'),
#                'ROE': Decimal('-0.1107'),
#                'Liq.2meses': Decimal('1044060.00'),
#                'Pat.Liq': Decimal('141721000.00'),
#                'Div.Brut/Pat.': Decimal('0.83'),
#                'Cresc.5anos': Decimal('-0.4002')}),
#              ('CTKA3',
#               {'Cotacao': Decimal('21.72'),
#                'P/L': Decimal('-8.79'),
#                'P/VP': Decimal('-0.83'),
#                'PSR': Decimal('0.219'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.224'),
#                'P/Cap.Giro': Decimal('0.97'),
#                'P/EBIT': Decimal('5.70'),
#                'P/ACL': Decimal('-0.38'),
#                'EV/EBIT': Decimal('29.16'),
#                'EV/EBITDA': Decimal('17.63'),
#                'Mrg.Ebit': Decimal('0.0385'),
#                'Mrg.Liq.': Decimal('-0.025'),
#                'Liq.Corr.': Decimal('1.52'),
#                'ROIC': Decimal('0.0445'),
#                'ROE': Decimal('0.0944'),
#                'Liq.2meses': Decimal('160.20'),
#                'Pat.Liq': Decimal('-162561000.00'),
#                'Div.Brut/Pat.': Decimal('-3.47'),
#                'Cresc.5anos': Decimal('0.1887')}),
#              ('RCSL4',
#               {'Cotacao': Decimal('0.72'),
#                'P/L': Decimal('-8.79'),
#                'P/VP': Decimal('-0.70'),
#                'PSR': Decimal('0.388'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.415'),
#                'P/Cap.Giro': Decimal('4.48'),
#                'P/EBIT': Decimal('129.37'),
#                'P/ACL': Decimal('-0.37'),
#                'EV/EBIT': Decimal('125.08'),
#                'EV/EBITDA': Decimal('20.09'),
#                'Mrg.Ebit': Decimal('0.003'),
#                'Mrg.Liq.': Decimal('-0.044'),
#                'Liq.Corr.': Decimal('1.25'),
#                'ROIC': Decimal('0.0034'),
#                'ROE': Decimal('0.0796'),
#                'Liq.2meses': Decimal('273721.00'),
#                'Pat.Liq': Decimal('-39014000.00'),
#                'Div.Brut/Pat.': Decimal('-0.00'),
#                'Cresc.5anos': Decimal('1.5121')}),
#              ('MEAL3',
#               {'Cotacao': Decimal('2.72'),
#                'P/L': Decimal('-8.50'),
#                'P/VP': Decimal('0.74'),
#                'PSR': Decimal('0.339'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.277'),
#                'P/Cap.Giro': Decimal('-5.42'),
#                'P/EBIT': Decimal('-22.18'),
#                'P/ACL': Decimal('-0.69'),
#                'EV/EBIT': Decimal('-30.46'),
#                'EV/EBITDA': Decimal('17.13'),
#                'Mrg.Ebit': Decimal('-0.0153'),
#                'Mrg.Liq.': Decimal('-0.0399'),
#                'Liq.Corr.': Decimal('0.81'),
#                'ROIC': Decimal('-0.0148'),
#                'ROE': Decimal('-0.0865'),
#                'Liq.2meses': Decimal('4840050.00'),
#                'Pat.Liq': Decimal('1059710000.00'),
#                'Div.Brut/Pat.': Decimal('0.52'),
#                'Cresc.5anos': Decimal('0.0843')}),
#              ('KRSA3',
#               {'Cotacao': Decimal('1.13'),
#                'P/L': Decimal('-7.13'),
#                'P/VP': Decimal('0.73'),
#                'PSR': Decimal('0.454'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.180'),
#                'P/Cap.Giro': Decimal('1.88'),
#                'P/EBIT': Decimal('4.24'),
#                'P/ACL': Decimal('-0.42'),
#                'EV/EBIT': Decimal('14.16'),
#                'EV/EBITDA': Decimal('9.29'),
#                'Mrg.Ebit': Decimal('0.107'),
#                'Mrg.Liq.': Decimal('-0.0574'),
#                'Liq.Corr.': Decimal('1.46'),
#                'ROIC': Decimal('0.0484'),
#                'ROE': Decimal('-0.1027'),
#                'Liq.2meses': Decimal('296321.00'),
#                'Pat.Liq': Decimal('1192960000.00'),
#                'Div.Brut/Pat.': Decimal('2.08'),
#                'Cresc.5anos': Decimal('0.00')}),
#              ('GFSA3',
#               {'Cotacao': Decimal('5.69'),
#                'P/L': Decimal('-7.07'),
#                'P/VP': Decimal('0.12'),
#                'PSR': Decimal('0.209'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.037'),
#                'P/Cap.Giro': Decimal('0.11'),
#                'P/EBIT': Decimal('-25.57'),
#                'P/ACL': Decimal('-1.75'),
#                'EV/EBIT': Decimal('-220.00'),
#                'EV/EBITDA': Decimal('77.17'),
#                'Mrg.Ebit': Decimal('-0.0082'),
#                'Mrg.Liq.': Decimal('-0.0299'),
#                'Liq.Corr.': Decimal('1.93'),
#                'ROIC': Decimal('-0.0016'),
#                'ROE': Decimal('-0.0175'),
#                'Liq.2meses': Decimal('14061000.00'),
#                'Pat.Liq': Decimal('1741480000.00'),
#                'Div.Brut/Pat.': Decimal('1.28'),
#                'Cresc.5anos': Decimal('0.1169')}),
#              ('TCNO3',
#               {'Cotacao': Decimal('1.20'),
#                'P/L': Decimal('-6.81'),
#                'P/VP': Decimal('-8.40'),
#                'PSR': Decimal('0.000'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.034'),
#                'P/Cap.Giro': Decimal('-0.08'),
#                'P/EBIT': Decimal('-2.87'),
#                'P/ACL': Decimal('-0.04'),
#                'EV/EBIT': Decimal('-15.11'),
#                'EV/EBITDA': Decimal('-17.45'),
#                'Mrg.Ebit': Decimal('0.00'),
#                'Mrg.Liq.': Decimal('0.00'),
#                'Liq.Corr.': Decimal('0.28'),
#                'ROIC': Decimal('-0.0159'),
#                'ROE': Decimal('1.2336'),
#                'Liq.2meses': Decimal('973.46'),
#                'Pat.Liq': Decimal('-946000.00'),
#                'Div.Brut/Pat.': Decimal('-35.76'),
#                'Cresc.5anos': Decimal('-0.3239')}),
#              ('TELB3',
#               {'Cotacao': Decimal('14.89'),
#                'P/L': Decimal('-6.66'),
#                'P/VP': Decimal('0.61'),
#                'PSR': Decimal('2.939'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.252'),
#                'P/Cap.Giro': Decimal('0.84'),
#                'P/EBIT': Decimal('-3.54'),
#                'P/ACL': Decimal('-1.20'),
#                'EV/EBIT': Decimal('-0.18'),
#                'EV/EBITDA': Decimal('-1.14'),
#                'Mrg.Ebit': Decimal('-0.8306'),
#                'Mrg.Liq.': Decimal('-0.4411'),
#                'Liq.Corr.': Decimal('4.98'),
#                'ROIC': Decimal('-0.1025'),
#                'ROE': Decimal('-0.0915'),
#                'Liq.2meses': Decimal('38105.90'),
#                'Pat.Liq': Decimal('1657470000.00'),
#                'Div.Brut/Pat.': Decimal('0.11'),
#                'Cresc.5anos': Decimal('0.5899')}),
#              ('PEAB4',
#               {'Cotacao': Decimal('58.05'),
#                'P/L': Decimal('-6.66'),
#                'P/VP': Decimal('1.10'),
#                'PSR': Decimal('19.931'),
#                'DY': Decimal('0.0329'),
#                'P/Ativo': Decimal('0.927'),
#                'P/Cap.Giro': Decimal('3.36'),
#                'P/EBIT': Decimal('-118.63'),
#                'P/ACL': Decimal('6.67'),
#                'EV/EBIT': Decimal('-97.64'),
#                'EV/EBITDA': Decimal('-212.81'),
#                'Mrg.Ebit': Decimal('-0.168'),
#                'Mrg.Liq.': Decimal('-2.9864'),
#                'Liq.Corr.': Decimal('14.20'),
#                'ROIC': Decimal('-0.0103'),
#                'ROE': Decimal('-0.1652'),
#                'Liq.2meses': Decimal('4263.20'),
#                'Pat.Liq': Decimal('678038000.00'),
#                'Div.Brut/Pat.': Decimal('0.09'),
#                'Cresc.5anos': Decimal('-0.5186')}),
#              ('SEQL3',
#               {'Cotacao': Decimal('3.23'),
#                'P/L': Decimal('-6.55'),
#                'P/VP': Decimal('0.84'),
#                'PSR': Decimal('0.245'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.231'),
#                'P/Cap.Giro': Decimal('-89.66'),
#                'P/EBIT': Decimal('15.34'),
#                'P/ACL': Decimal('-0.57'),
#                'EV/EBIT': Decimal('36.99'),
#                'EV/EBITDA': Decimal('6.07'),
#                'Mrg.Ebit': Decimal('0.016'),
#                'Mrg.Liq.': Decimal('-0.0374'),
#                'Liq.Corr.': Decimal('0.99'),
#                'ROIC': Decimal('0.0175'),
#                'ROE': Decimal('-0.1287'),
#                'Liq.2meses': Decimal('19907900.00'),
#                'Pat.Liq': Decimal('537366000.00'),
#                'Div.Brut/Pat.': Decimal('1.32'),
#                'Cresc.5anos': Decimal('0.3084')}),
#              ('NINJ3',
#               {'Cotacao': Decimal('2.85'),
#                'P/L': Decimal('-6.47'),
#                'P/VP': Decimal('0.52'),
#                'PSR': Decimal('2.434'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.477'),
#                'P/Cap.Giro': Decimal('0.54'),
#                'P/EBIT': Decimal('-2.76'),
#                'P/ACL': Decimal('0.55'),
#                'EV/EBIT': Decimal('2.59'),
#                'EV/EBITDA': Decimal('2.63'),
#                'Mrg.Ebit': Decimal('-0.8816'),
#                'Mrg.Liq.': Decimal('-0.376'),
#                'Liq.Corr.': Decimal('13.24'),
#                'ROIC': Decimal('-3.6627'),
#                'ROE': Decimal('-0.0797'),
#                'Liq.2meses': Decimal('486876.00'),
#                'Pat.Liq': Decimal('277516000.00'),
#                'Div.Brut/Pat.': Decimal('0.00'),
#                'Cresc.5anos': Decimal('0.00')}),
#              ('SEER3',
#               {'Cotacao': Decimal('4.52'),
#                'P/L': Decimal('-6.24'),
#                'P/VP': Decimal('0.43'),
#                'PSR': Decimal('0.358'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.167'),
#                'P/Cap.Giro': Decimal('2.46'),
#                'P/EBIT': Decimal('2.78'),
#                'P/ACL': Decimal('-0.43'),
#                'EV/EBIT': Decimal('5.09'),
#                'EV/EBITDA': Decimal('2.56'),
#                'Mrg.Ebit': Decimal('0.1286'),
#                'Mrg.Liq.': Decimal('-0.0574'),
#                'Liq.Corr.': Decimal('1.44'),
#                'ROIC': Decimal('0.0658'),
#                'ROE': Decimal('-0.0684'),
#                'Liq.2meses': Decimal('5532000.00'),
#                'Pat.Liq': Decimal('1363920000.00'),
#                'Div.Brut/Pat.': Decimal('0.55'),
#                'Cresc.5anos': Decimal('0.0627')}),
#              ('CRDE3',
#               {'Cotacao': Decimal('18.00'),
#                'P/L': Decimal('-6.23'),
#                'P/VP': Decimal('0.46'),
#                'PSR': Decimal('6.359'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.393'),
#                'P/Cap.Giro': Decimal('12.20'),
#                'P/EBIT': Decimal('-4.62'),
#                'P/ACL': Decimal('-22.04'),
#                'EV/EBIT': Decimal('-3.53'),
#                'EV/EBITDA': Decimal('-3.55'),
#                'Mrg.Ebit': Decimal('-1.3763'),
#                'Mrg.Liq.': Decimal('-1.0235'),
#                'Liq.Corr.': Decimal('1.34'),
#                'ROIC': Decimal('-0.0963'),
#                'ROE': Decimal('-0.0741'),
#                'Liq.2meses': Decimal('2652.98'),
#                'Pat.Liq': Decimal('94414000.00'),
#                'Div.Brut/Pat.': Decimal('0.00'),
#                'Cresc.5anos': Decimal('-0.2717')}),
#              ('BRFS3',
#               {'Cotacao': Decimal('7.14'),
#                'P/L': Decimal('-5.80'),
#                'P/VP': Decimal('0.64'),
#                'PSR': Decimal('0.146'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.131'),
#                'P/Cap.Giro': Decimal('1.29'),
#                'P/EBIT': Decimal('6.86'),
#                'P/ACL': Decimal('-0.41'),
#                'EV/EBIT': Decimal('20.42'),
#                'EV/EBITDA': Decimal('5.74'),
#                'Mrg.Ebit': Decimal('0.0214'),
#                'Mrg.Liq.': Decimal('-0.0237'),
#                'Liq.Corr.': Decimal('1.28'),
#                'ROIC': Decimal('0.0319'),
#                'ROE': Decimal('-0.1111'),
#                'Liq.2meses': Decimal('152095000.00'),
#                'Pat.Liq': Decimal('12000400000.00'),
#                'Div.Brut/Pat.': Decimal('2.00'),
#                'Cresc.5anos': Decimal('0.1425')}),
#              ('BLUT3',
#               {'Cotacao': Decimal('5.14'),
#                'P/L': Decimal('-5.63'),
#                'P/VP': Decimal('0.46'),
#                'PSR': Decimal('0.000'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.138'),
#                'P/Cap.Giro': Decimal('-0.76'),
#                'P/EBIT': Decimal('-42.93'),
#                'P/ACL': Decimal('-0.20'),
#                'EV/EBIT': Decimal('-53.97'),
#                'EV/EBITDA': Decimal('-53.97'),
#                'Mrg.Ebit': Decimal('0.00'),
#                'Mrg.Liq.': Decimal('0.00'),
#                'Liq.Corr.': Decimal('0.00'),
#                'ROIC': Decimal('-0.0033'),
#                'ROE': Decimal('-0.0824'),
#                'Liq.2meses': Decimal('3091.81'),
#                'Pat.Liq': Decimal('56569000.00'),
#                'Div.Brut/Pat.': Decimal('0.12'),
#                'Cresc.5anos': Decimal('0.00')}),
#              ('IFCM3',
#               {'Cotacao': Decimal('3.15'),
#                'P/L': Decimal('-5.27'),
#                'P/VP': Decimal('0.76'),
#                'PSR': Decimal('1.445'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.345'),
#                'P/Cap.Giro': Decimal('7.51'),
#                'P/EBIT': Decimal('-15.45'),
#                'P/ACL': Decimal('-1.74'),
#                'EV/EBIT': Decimal('-19.81'),
#                'EV/EBITDA': Decimal('39.06'),
#                'Mrg.Ebit': Decimal('-0.0935'),
#                'Mrg.Liq.': Decimal('-0.2741'),
#                'Liq.Corr.': Decimal('1.15'),
#                'ROIC': Decimal('-0.0301'),
#                'ROE': Decimal('-0.1438'),
#                'Liq.2meses': Decimal('3834360.00'),
#                'Pat.Liq': Decimal('1515790000.00'),
#                'Div.Brut/Pat.': Decimal('0.39'),
#                'Cresc.5anos': Decimal('0.00')}),
#              ('AHEB3',
#               {'Cotacao': Decimal('20.00'),
#                'P/L': Decimal('-5.16'),
#                'P/VP': Decimal('-2.11'),
#                'PSR': Decimal('0.820'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.589'),
#                'P/Cap.Giro': Decimal('-172.96'),
#                'P/EBIT': Decimal('-18.45'),
#                'P/ACL': Decimal('-0.58'),
#                'EV/EBIT': Decimal('-18.54'),
#                'EV/EBITDA': Decimal('-64.40'),
#                'Mrg.Ebit': Decimal('-0.0445'),
#                'Mrg.Liq.': Decimal('-0.1589'),
#                'Liq.Corr.': Decimal('0.99'),
#                'ROIC': Decimal('-0.0347'),
#                'ROE': Decimal('0.4093'),
#                'Liq.2meses': Decimal('634.39'),
#                'Pat.Liq': Decimal('-80875000.00'),
#                'Div.Brut/Pat.': Decimal('-0.05'),
#                'Cresc.5anos': Decimal('0.2572')}),
#              ('TCNO4',
#               {'Cotacao': Decimal('0.85'),
#                'P/L': Decimal('-4.82'),
#                'P/VP': Decimal('-5.95'),
#                'PSR': Decimal('0.000'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.024'),
#                'P/Cap.Giro': Decimal('-0.06'),
#                'P/EBIT': Decimal('-2.04'),
#                'P/ACL': Decimal('-0.03'),
#                'EV/EBIT': Decimal('-14.27'),
#                'EV/EBITDA': Decimal('-16.48'),
#                'Mrg.Ebit': Decimal('0.00'),
#                'Mrg.Liq.': Decimal('0.00'),
#                'Liq.Corr.': Decimal('0.28'),
#                'ROIC': Decimal('-0.0159'),
#                'ROE': Decimal('1.2336'),
#                'Liq.2meses': Decimal('2703.20'),
#                'Pat.Liq': Decimal('-946000.00'),
#                'Div.Brut/Pat.': Decimal('-35.76'),
#                'Cresc.5anos': Decimal('-0.3239')}),
#              ('BOBR4',
#               {'Cotacao': Decimal('1.16'),
#                'P/L': Decimal('-4.69'),
#                'P/VP': Decimal('-1.69'),
#                'PSR': Decimal('0.216'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.334'),
#                'P/Cap.Giro': Decimal('-1.19'),
#                'P/EBIT': Decimal('2.66'),
# ...
#                'Mrg.Ebit': Decimal('0.1821'),
#                'Mrg.Liq.': Decimal('0.1387'),
#                'Liq.Corr.': Decimal('1.81'),
#                'ROIC': Decimal('0.245'),
#                'ROE': Decimal('0.2799'),
#                'Liq.2meses': Decimal('352513000.00'),
#                'Pat.Liq': Decimal('13894500000.00'),
#                'Div.Brut/Pat.': Decimal('0.28'),
#                'Cresc.5anos': Decimal('0.2656')}),
#              ('RADL3',
#               {'Cotacao': Decimal('22.24'),
#                'P/L': Decimal('41.69'),
#                'P/VP': Decimal('7.27'),
#                'PSR': Decimal('1.326'),
#                'DY': Decimal('0.0114'),
#                'P/Ativo': Decimal('2.223'),
#                'P/Cap.Giro': Decimal('11.66'),
#                'P/EBIT': Decimal('22.89'),
#                'P/ACL': Decimal('-16.53'),
#                'EV/EBIT': Decimal('24.07'),
#                'EV/EBITDA': Decimal('12.71'),
#                'Mrg.Ebit': Decimal('0.0579'),
#                'Mrg.Liq.': Decimal('0.0326'),
#                'Liq.Corr.': Decimal('1.52'),
#                'ROIC': Decimal('0.1294'),
#                'ROE': Decimal('0.1744'),
#                'Liq.2meses': Decimal('205045000.00'),
#                'Pat.Liq': Decimal('5052790000.00'),
#                'Div.Brut/Pat.': Decimal('0.45'),
#                'Cresc.5anos': Decimal('0.179')}),
#              ('SULA3',
#               {'Cotacao': Decimal('6.18'),
#                'P/L': Decimal('43.52'),
#                'P/VP': Decimal('0.94'),
#                'PSR': Decimal('0.360'),
#                'DY': Decimal('0.0121'),
#                'P/Ativo': Decimal('0.261'),
#                'P/Cap.Giro': Decimal('0.71'),
#                'P/EBIT': Decimal('-10.89'),
#                'P/ACL': Decimal('-3.83'),
#                'EV/EBIT': Decimal('8.80'),
#                'EV/EBITDA': Decimal('11.31'),
#                'Mrg.Ebit': Decimal('-0.033'),
#                'Mrg.Liq.': Decimal('0.0083'),
#                'Liq.Corr.': Decimal('2.29'),
#                'ROIC': Decimal('-0.0562'),
#                'ROE': Decimal('0.0217'),
#                'Liq.2meses': Decimal('42130.90'),
#                'Pat.Liq': Decimal('8363840000.00'),
#                'Div.Brut/Pat.': Decimal('0.37'),
#                'Cresc.5anos': Decimal('0.0166')}),
#              ('SULA11',
#               {'Cotacao': Decimal('19.09'),
#                'P/L': Decimal('44.81'),
#                'P/VP': Decimal('0.97'),
#                'PSR': Decimal('0.371'),
#                'DY': Decimal('0.0118'),
#                'P/Ativo': Decimal('0.269'),
#                'P/Cap.Giro': Decimal('0.73'),
#                'P/EBIT': Decimal('-11.21'),
#                'P/ACL': Decimal('-3.95'),
#                'EV/EBIT': Decimal('8.47'),
#                'EV/EBITDA': Decimal('10.89'),
#                'Mrg.Ebit': Decimal('-0.033'),
#                'Mrg.Liq.': Decimal('0.0083'),
#                'Liq.Corr.': Decimal('2.29'),
#                'ROIC': Decimal('-0.0562'),
#                'ROE': Decimal('0.0217'),
#                'Liq.2meses': Decimal('83118400.00'),
#                'Pat.Liq': Decimal('8363840000.00'),
#                'Div.Brut/Pat.': Decimal('0.37'),
#                'Cresc.5anos': Decimal('0.0166')}),
#              ('SULA4',
#               {'Cotacao': Decimal('6.72'),
#                'P/L': Decimal('47.32'),
#                'P/VP': Decimal('1.03'),
#                'PSR': Decimal('0.391'),
#                'DY': Decimal('0.0111'),
#                'P/Ativo': Decimal('0.284'),
#                'P/Cap.Giro': Decimal('0.77'),
#                'P/EBIT': Decimal('-11.84'),
#                'P/ACL': Decimal('-4.17'),
#                'EV/EBIT': Decimal('7.85'),
#                'EV/EBITDA': Decimal('10.09'),
#                'Mrg.Ebit': Decimal('-0.033'),
#                'Mrg.Liq.': Decimal('0.0083'),
#                'Liq.Corr.': Decimal('2.29'),
#                'ROIC': Decimal('-0.0562'),
#                'ROE': Decimal('0.0217'),
#                'Liq.2meses': Decimal('81500.50'),
#                'Pat.Liq': Decimal('8363840000.00'),
#                'Div.Brut/Pat.': Decimal('0.37'),
#                'Cresc.5anos': Decimal('0.0166')}),
#              ('BAUH4',
#               {'Cotacao': Decimal('83.89'),
#                'P/L': Decimal('48.07'),
#                'P/VP': Decimal('4.07'),
#                'PSR': Decimal('2.391'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('2.647'),
#                'P/Cap.Giro': Decimal('94.33'),
#                'P/EBIT': Decimal('141.50'),
#                'P/ACL': Decimal('-71.22'),
#                'EV/EBIT': Decimal('141.47'),
#                'EV/EBITDA': Decimal('53.20'),
#                'Mrg.Ebit': Decimal('0.0169'),
#                'Mrg.Liq.': Decimal('0.0497'),
#                'Liq.Corr.': Decimal('1.10'),
#                'ROIC': Decimal('0.0243'),
#                'ROE': Decimal('0.0846'),
#                'Liq.2meses': Decimal('5358.68'),
#                'Pat.Liq': Decimal('107672000.00'),
#                'Div.Brut/Pat.': Decimal('0.14'),
#                'Cresc.5anos': Decimal('0.014')}),
#              ('PETZ3',
#               {'Cotacao': Decimal('6.29'),
#                'P/L': Decimal('48.26'),
#                'P/VP': Decimal('1.59'),
#                'PSR': Decimal('1.100'),
#                'DY': Decimal('0.0054'),
#                'P/Ativo': Decimal('0.812'),
#                'P/Cap.Giro': Decimal('6.36'),
#                'P/EBIT': Decimal('13.14'),
#                'P/ACL': Decimal('-4.77'),
#                'EV/EBIT': Decimal('12.53'),
#                'EV/EBITDA': Decimal('5.93'),
#                'Mrg.Ebit': Decimal('0.0837'),
#                'Mrg.Liq.': Decimal('0.0228'),
#                'Liq.Corr.': Decimal('1.67'),
#                'ROIC': Decimal('0.0736'),
#                'ROE': Decimal('0.0329'),
#                'Liq.2meses': Decimal('116513000.00'),
#                'Pat.Liq': Decimal('1831130000.00'),
#                'Div.Brut/Pat.': Decimal('0.07'),
#                'Cresc.5anos': Decimal('0.3552')}),
#              ('LUXM4',
#               {'Cotacao': Decimal('81.98'),
#                'P/L': Decimal('50.39'),
#                'P/VP': Decimal('3.95'),
#                'PSR': Decimal('3.113'),
#                'DY': Decimal('0.0085'),
#                'P/Ativo': Decimal('2.783'),
#                'P/Cap.Giro': Decimal('-817.60'),
#                'P/EBIT': Decimal('20.57'),
#                'P/ACL': Decimal('-19.87'),
#                'EV/EBIT': Decimal('20.49'),
#                'EV/EBITDA': Decimal('11.70'),
#                'Mrg.Ebit': Decimal('0.1513'),
#                'Mrg.Liq.': Decimal('0.0618'),
#                'Liq.Corr.': Decimal('0.98'),
#                'ROIC': Decimal('0.1509'),
#                'ROE': Decimal('0.0784'),
#                'Liq.2meses': Decimal('109663.00'),
#                'Pat.Liq': Decimal('107812000.00'),
#                'Div.Brut/Pat.': Decimal('0.10'),
#                'Cresc.5anos': Decimal('0.0219')}),
#              ('AURE3',
#               {'Cotacao': Decimal('14.04'),
#                'P/L': Decimal('54.27'),
#                'P/VP': Decimal('1.08'),
#                'PSR': Decimal('2.862'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.479'),
#                'P/Cap.Giro': Decimal('5.86'),
#                'P/EBIT': Decimal('19.97'),
#                'P/ACL': Decimal('-1.29'),
#                'EV/EBIT': Decimal('23.99'),
#                'EV/EBITDA': Decimal('12.74'),
#                'Mrg.Ebit': Decimal('0.1433'),
#                'Mrg.Liq.': Decimal('0.0545'),
#                'Liq.Corr.': Decimal('1.77'),
#                'ROIC': Decimal('0.0272'),
#                'ROE': Decimal('0.02'),
#                'Liq.2meses': Decimal('53817900.00'),
#                'Pat.Liq': Decimal('12950500000.00'),
#                'Div.Brut/Pat.': Decimal('0.45'),
#                'Cresc.5anos': Decimal('0.00')}),
#              ('MOAR3',
#               {'Cotacao': Decimal('483.00'),
#                'P/L': Decimal('56.03'),
#                'P/VP': Decimal('7.15'),
#                'PSR': Decimal('128636.000'),
#                'DY': Decimal('0.0406'),
#                'P/Ativo': Decimal('2.895'),
#                'P/Cap.Giro': Decimal('10.58'),
#                'P/EBIT': Decimal('-168.25'),
#                'P/ACL': Decimal('-16.03'),
#                'EV/EBIT': Decimal('-170.19'),
#                'EV/EBITDA': Decimal('-173.63'),
#                'Mrg.Ebit': Decimal('-764.543'),
#                'Mrg.Liq.': Decimal('2296.02'),
#                'Liq.Corr.': Decimal('2.94'),
#                'ROIC': Decimal('-0.0289'),
#                'ROE': Decimal('0.1277'),
#                'Liq.2meses': Decimal('262150.00'),
#                'Pat.Liq': Decimal('827321000.00'),
#                'Div.Brut/Pat.': Decimal('1.08'),
#                'Cresc.5anos': Decimal('-0.532')}),
#              ('CPLE5',
#               {'Cotacao': Decimal('23.12'),
#                'P/L': Decimal('72.03'),
#                'P/VP': Decimal('3.02'),
#                'PSR': Decimal('2.763'),
#                'DY': Decimal('0.0429'),
#                'P/Ativo': Decimal('1.269'),
#                'P/Cap.Giro': Decimal('16.88'),
#                'P/EBIT': Decimal('17.01'),
#                'P/ACL': Decimal('-3.54'),
#                'EV/EBIT': Decimal('19.43'),
#                'EV/EBITDA': Decimal('14.48'),
#                'Mrg.Ebit': Decimal('0.1624'),
#                'Mrg.Liq.': Decimal('0.0403'),
#                'Liq.Corr.': Decimal('1.54'),
#                'ROIC': Decimal('0.0856'),
#                'ROE': Decimal('0.0419'),
#                'Liq.2meses': Decimal('1782.44'),
#                'Pat.Liq': Decimal('20969700000.00'),
#                'Div.Brut/Pat.': Decimal('0.64'),
#                'Cresc.5anos': Decimal('0.1289')}),
#              ('PDTC3',
#               {'Cotacao': Decimal('2.95'),
#                'P/L': Decimal('104.25'),
#                'P/VP': Decimal('1.77'),
#                'PSR': Decimal('0.646'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.477'),
#                'P/Cap.Giro': Decimal('1.41'),
#                'P/EBIT': Decimal('16.87'),
#                'P/ACL': Decimal('-29.24'),
#                'EV/EBIT': Decimal('22.03'),
#                'EV/EBITDA': Decimal('9.83'),
#                'Mrg.Ebit': Decimal('0.0383'),
#                'Mrg.Liq.': Decimal('0.0062'),
#                'Liq.Corr.': Decimal('1.90'),
#                'ROIC': Decimal('0.0364'),
#                'ROE': Decimal('0.017'),
#                'Liq.2meses': Decimal('183923.00'),
#                'Pat.Liq': Decimal('130596000.00'),
#                'Div.Brut/Pat.': Decimal('0.90'),
#                'Cresc.5anos': Decimal('1.0277')}),
#              ('AMER3',
#               {'Cotacao': Decimal('8.14'),
#                'P/L': Decimal('172.83'),
#                'P/VP': Decimal('0.50'),
#                'PSR': Decimal('0.265'),
#                'DY': Decimal('0.0758'),
#                'P/Ativo': Decimal('0.157'),
#                'P/Cap.Giro': Decimal('0.60'),
#                'P/EBIT': Decimal('6.14'),
#                'P/ACL': Decimal('-0.75'),
#                'EV/EBIT': Decimal('16.24'),
#                'EV/EBITDA': Decimal('6.19'),
#                'Mrg.Ebit': Decimal('0.0431'),
#                'Mrg.Liq.': Decimal('0.0015'),
#                'Liq.Corr.': Decimal('2.24'),
#                'ROIC': Decimal('0.0361'),
#                'ROE': Decimal('0.0029'),
#                'Liq.2meses': Decimal('397792000.00'),
#                'Pat.Liq': Decimal('14705600000.00'),
#                'Div.Brut/Pat.': Decimal('1.41'),
#                'Cresc.5anos': Decimal('0.4703')}),
#              ('NGRD3',
#               {'Cotacao': Decimal('1.42'),
#                'P/L': Decimal('254.81'),
#                'P/VP': Decimal('0.75'),
#                'PSR': Decimal('1.288'),
#                'DY': Decimal('0.0105'),
#                'P/Ativo': Decimal('0.472'),
#                'P/Cap.Giro': Decimal('1.68'),
#                'P/EBIT': Decimal('36.34'),
#                'P/ACL': Decimal('4.78'),
#                'EV/EBIT': Decimal('15.39'),
#                'EV/EBITDA': Decimal('3.88'),
#                'Mrg.Ebit': Decimal('0.0354'),
#                'Mrg.Liq.': Decimal('0.0031'),
#                'Liq.Corr.': Decimal('2.48'),
#                'ROIC': Decimal('0.0219'),
#                'ROE': Decimal('0.0029'),
#                'Liq.2meses': Decimal('1218430.00'),
#                'Pat.Liq': Decimal('451675000.00'),
#                'Div.Brut/Pat.': Decimal('0.16'),
#                'Cresc.5anos': Decimal('0.1122')}),
#              ('LJQQ3',
#               {'Cotacao': Decimal('4.20'),
#                'P/L': Decimal('280.33'),
#                'P/VP': Decimal('1.51'),
#                'PSR': Decimal('0.348'),
#                'DY': Decimal('0.0292'),
#                'P/Ativo': Decimal('0.278'),
#                'P/Cap.Giro': Decimal('0.89'),
#                'P/EBIT': Decimal('7.72'),
#                'P/ACL': Decimal('-1.77'),
#                'EV/EBIT': Decimal('6.93'),
#                'EV/EBITDA': Decimal('3.50'),
#                'Mrg.Ebit': Decimal('0.0451'),
#                'Mrg.Liq.': Decimal('0.0012'),
#                'Liq.Corr.': Decimal('1.91'),
#                'ROIC': Decimal('0.0482'),
#                'ROE': Decimal('0.0054'),
#                'Liq.2meses': Decimal('19415300.00'),
#                'Pat.Liq': Decimal('520369000.00'),
#                'Div.Brut/Pat.': Decimal('0.65'),
#                'Cresc.5anos': Decimal('0.1463')}),
#              ('IGTI3',
#               {'Cotacao': Decimal('2.38'),
#                'P/L': Decimal('313.89'),
#                'P/VP': Decimal('1.25'),
#                'PSR': Decimal('4.814'),
#                'DY': Decimal('0.011'),
#                'P/Ativo': Decimal('0.663'),
#                'P/Cap.Giro': Decimal('3.90'),
#                'P/EBIT': Decimal('10.43'),
#                'P/ACL': Decimal('-4.54'),
#                'EV/EBIT': Decimal('12.90'),
#                'EV/EBITDA': Decimal('9.69'),
#                'Mrg.Ebit': Decimal('0.4614'),
#                'Mrg.Liq.': Decimal('-0.0019'),
#                'Liq.Corr.': Decimal('2.11'),
#                'ROIC': Decimal('0.0876'),
#                'ROE': Decimal('0.004'),
#                'Liq.2meses': Decimal('547704.00'),
#                'Pat.Liq': Decimal('4002910000.00'),
#                'Div.Brut/Pat.': Decimal('0.81'),
#                'Cresc.5anos': Decimal('0.0775')}),
#              ('IGTI11',
#               {'Cotacao': Decimal('17.32'),
#                'P/L': Decimal('326.32'),
#                'P/VP': Decimal('1.30'),
#                'PSR': Decimal('5.005'),
#                'DY': Decimal('0.0105'),
#                'P/Ativo': Decimal('0.689'),
#                'P/Cap.Giro': Decimal('4.06'),
#                'P/EBIT': Decimal('10.85'),
#                'P/ACL': Decimal('-4.72'),
#                'EV/EBIT': Decimal('13.31'),
#                'EV/EBITDA': Decimal('10.01'),
#                'Mrg.Ebit': Decimal('0.4614'),
#                'Mrg.Liq.': Decimal('-0.0019'),
#                'Liq.Corr.': Decimal('2.11'),
#                'ROIC': Decimal('0.0876'),
#                'ROE': Decimal('0.004'),
#                'Liq.2meses': Decimal('67674900.00'),
#                'Pat.Liq': Decimal('4002910000.00'),
#                'Div.Brut/Pat.': Decimal('0.81'),
#                'Cresc.5anos': Decimal('0.0775')}),
#              ('LWSA3',
#               {'Cotacao': Decimal('7.08'),
#                'P/L': Decimal('999.76'),
#                'P/VP': Decimal('1.42'),
#                'PSR': Decimal('3.879'),
#                'DY': Decimal('0.00'),
#                'P/Ativo': Decimal('0.908'),
#                'P/Cap.Giro': Decimal('3.79'),
#                'P/EBIT': Decimal('148.40'),
#                'P/ACL': Decimal('9.66'),
#                'EV/EBIT': Decimal('100.96'),
#                'EV/EBITDA': Decimal('22.19'),
#                'Mrg.Ebit': Decimal('0.0261'),
#                'Mrg.Liq.': Decimal('0.0039'),
#                'Liq.Corr.': Decimal('2.12'),
#                'ROIC': Decimal('0.009'),
#                'ROE': Decimal('0.0014'),
#                'Liq.2meses': Decimal('93430200.00'),
#                'Pat.Liq': Decimal('2959840000.00'),
#                'Div.Brut/Pat.': Decimal('0.03'),
#                'Cresc.5anos': Decimal('0.5447')})])

# %%
final_df = pd.DataFrame(final_dict).transpose()

# %%
final_df.reset_index().rename(columns={'index':'COD_ACAO'},inplace=True)

# %%
final_df
# Out:
#        Cotacao       P/L   P/VP    PSR      DY P/Ativo P/Cap.Giro  P/EBIT  \
# AESB3     9.38  -1387.24   1.35  2.005  0.0094   0.374       1.90   11.08
# ONCO3     6.12   -318.86   1.51  0.838    0.00   0.419       4.95    8.83
# RAIL3    16.91   -282.74   2.08  3.433  0.0011   0.689       6.82   14.18
# DMMO3     1.86   -258.31  -1.71  2.851    0.00   3.341      11.89    6.36
# ELMD3     9.70   -165.61   1.84  1.941    0.00   0.680      -6.77   15.60
# ...        ...       ...    ...    ...     ...     ...        ...     ...
# NGRD3     1.42    254.81   0.75  1.288  0.0105   0.472       1.68   36.34
# LJQQ3     4.20    280.33   1.51  0.348  0.0292   0.278       0.89    7.72
# IGTI3     2.38    313.89   1.25  4.814   0.011   0.663       3.90   10.43
# IGTI11   17.32    326.32   1.30  5.005  0.0105   0.689       4.06   10.85
# LWSA3     7.08    999.76   1.42  3.879    0.00   0.908       3.79  148.40
#
#         P/ACL EV/EBIT EV/EBITDA Mrg.Ebit Mrg.Liq. Liq.Corr.    ROIC      ROE  \
# AESB3   -1.00   19.79     10.02    0.181   0.0537      3.63  0.0448   -0.001
# ONCO3   -1.16   15.75     10.60   0.0949   0.0109      1.42  0.0557  -0.0047
# RAIL3   -1.56   18.79      9.95   0.2421  -0.0124      1.83  0.0577  -0.0074
# DMMO3   -1.37    5.89      5.41   0.4481   -0.011      2.25  0.7039   0.0066
# ELMD3   -1.80   21.78      9.95   0.1244   0.0024      0.64  0.0504  -0.0111
# ...       ...     ...       ...      ...      ...       ...     ...      ...
# NGRD3    4.78   15.39      3.88   0.0354   0.0031      2.48  0.0219   0.0029
# LJQQ3   -1.77    6.93      3.50   0.0451   0.0012      1.91  0.0482   0.0054
# IGTI3   -4.54   12.90      9.69   0.4614  -0.0019      2.11  0.0876    0.004
# IGTI11  -4.72   13.31     10.01   0.4614  -0.0019      2.11  0.0876    0.004
# LWSA3    9.66  100.96     22.19   0.0261   0.0039      2.12   0.009   0.0014
#
#           Liq.2meses         Pat.Liq Div.Brut/Pat. Cresc.5anos
# AESB3    20667900.00   4175170000.00          1.89      1.3024
# ONCO3     8085020.00   2014190000.00          1.48        0.00
# RAIL3   268912000.00  15061000000.00          1.11       0.077
# DMMO3    17338800.00   -553275000.00          0.00     -0.1737
# ELMD3     3058160.00    739445000.00          0.91       1.011
# ...              ...             ...           ...         ...
# NGRD3     1218430.00    451675000.00          0.16      0.1122
# LJQQ3    19415300.00    520369000.00          0.65      0.1463
# IGTI3      547704.00   4002910000.00          0.81      0.0775
# IGTI11   67674900.00   4002910000.00          0.81      0.0775
# LWSA3    93430200.00   2959840000.00          0.03      0.5447
#
# [460 rows x 20 columns]
